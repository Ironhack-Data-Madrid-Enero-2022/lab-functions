# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a < b:
        resultado = b
    else:
        resultado = a
    return resultado
    pass

# %%
greater(2,3)
# Out:
# 3

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.045s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
lista = ["cuadrado", "rectangulo", "circulo", "octogono"]
type(list)
# Out:
# list

# %%
def greatest(arr):
    length = 0
    for i in arr:
        for x in i:
            length+=1
    return length

# %%
greatest(lista)
# Out:
# 33

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ======================================================================
# ERROR: runTest (mod.testing.test_greatest.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/marilyngutierrez/Desktop/ironhack/week1/lab-functions/mod/testing.py", line 32, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/var/folders/w9/4yhw7p0960dgdz88wgvm_0cm0000gn/T/ipykernel_1387/3377370926.py", line 3, in greatest
#     long = max(len(i))
# TypeError: object of type 'int' has no len()
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.080s
#
# FAILED (errors=100)

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
elementos = [1,2,4,5,7,8,9]
def sum_all(arr):
    resultado = 0
    for i in arr:
        resultado += i
    return resultado

# %%
sum_all(elementos)
# Out:
# 36

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.047s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
elementos = [2,2,6,7,8,9]
def mult_all(arr):
    result = 1
    for i in arr:
        result *= i
    return result

# %%
mult_all(elementos)
# Out:
# 12096

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.046s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
operaciones = [2,3]
def oper_all(arr, oper):
    resultado_6 = 0
    if oper == "+":
        for i in arr:
            resultado_6 += i
    if oper == "*":
        resultado_6 = 1
        for i in arr:
            resultado_6 *= i
    return resultado_6

# %%
oper_all(operaciones, "*")
# Out:
# 6

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.048s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def fact_1(n):
    factorial_total = 1
    while n > 1:
        factorial_total *= n
        n -= 1
    return factorial_total

# %%
fact_1(3)
# Out:
# 6

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.043s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
lista = ["a","b","c","c","c","b","b"]
def unique(arr):
    new = []
    for i in arr:
        if i not in new:
            new.append(i)
    return new

# %%
unique(lista)
# Out:
# ['a', 'b', 'c']

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.111s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
lista = [1,2,3,4,5,5,5,5,6,7]
def mode_counter(arr):
    y ={}
    for i in arr:
        if not i in y:
            y[i]=1
        else:
            y[i]+=1
    for r,l in y.items():
        if l==max(y.values()):
            return r

# %%
mode_counter(lista)
# Out:
# 5

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.051s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
from statistics import stdev
def st_dev(arr):
    pass

# %%
# This will test your function 
test_stdev(st_dev)

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    pass

# %%
# This will test your function 
test_pangram(pangram)

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    pass

# %%
# This will test your function 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
    pass

# %%
# This will test your function 
test_pass(check_pass)
