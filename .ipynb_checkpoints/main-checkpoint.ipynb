# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a>b:
        return f"Este el mayor: {a}!"
    elif a==b:
        return f"Son iguales"
    else:
        return f"Este es el mayor: {b}"

# %%
greater(5,9)
# Out:
# 'Este es el mayor: 9'

# %%
# This will test your function 
test_greater(greater)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: -672' != -672 : Should be -672
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 321!' != 321 : Should be 321
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 532!' != 532 : Should be 532
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 57!' != 57 : Should be 57
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 625' != 625 : Should be 625
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 519' != 519 : Should be 519
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 411' != 411 : Should be 411
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -320!' != -320 : Should be -320
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 682!' != 682 : Should be 682
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 99' != 99 : Should be 99
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 9!' != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 200' != 200 : Should be 200
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 32!' != 32 : Should be 32
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 267' != 267 : Should be 267
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -201!' != -201 : Should be -201
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 938' != 938 : Should be 938
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 656!' != 656 : Should be 656
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -458!' != -458 : Should be -458
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 913' != 913 : Should be 913
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -360!' != -360 : Should be -360
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 539' != 539 : Should be 539
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 975' != 975 : Should be 975
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 64!' != 64 : Should be 64
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 417' != 417 : Should be 417
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 85' != 85 : Should be 85
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 847' != 847 : Should be 847
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 495!' != 495 : Should be 495
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: -227' != -227 : Should be -227
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 601' != 601 : Should be 601
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -494!' != -494 : Should be -494
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 31!' != 31 : Should be 31
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 742' != 742 : Should be 742
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 38' != 38 : Should be 38
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 739!' != 739 : Should be 739
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 783' != 783 : Should be 783
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 716' != 716 : Should be 716
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 385' != 385 : Should be 385
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 227!' != 227 : Should be 227
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 703!' != 703 : Should be 703
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 323!' != 323 : Should be 323
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 214!' != 214 : Should be 214
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 150!' != 150 : Should be 150
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 856' != 856 : Should be 856
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 401!' != 401 : Should be 401
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 166' != 166 : Should be 166
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -204!' != -204 : Should be -204
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 43!' != 43 : Should be 43
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 935!' != 935 : Should be 935
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -186!' != -186 : Should be -186
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 147!' != 147 : Should be 147
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 484' != 484 : Should be 484
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 165!' != 165 : Should be 165
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 987' != 987 : Should be 987
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 708!' != 708 : Should be 708
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 371!' != 371 : Should be 371
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: -418' != -418 : Should be -418
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 14!' != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 955!' != 955 : Should be 955
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 272!' != 272 : Should be 272
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 525' != 525 : Should be 525
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -394!' != -394 : Should be -394
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 905!' != 905 : Should be 905
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 899!' != 899 : Should be 899
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 680!' != 680 : Should be 680
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 480!' != 480 : Should be 480
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 320' != 320 : Should be 320
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 908!' != 908 : Should be 908
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 67' != 67 : Should be 67
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -110!' != -110 : Should be -110
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: -280' != -280 : Should be -280
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 658' != 658 : Should be 658
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 730!' != 730 : Should be 730
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 934' != 934 : Should be 934
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 543!' != 543 : Should be 543
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 636!' != 636 : Should be 636
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 14!' != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 760!' != 760 : Should be 760
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 857!' != 857 : Should be 857
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 959!' != 959 : Should be 959
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 602' != 602 : Should be 602
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 983!' != 983 : Should be 983
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 27!' != 27 : Should be 27
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: -223' != -223 : Should be -223
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: -117' != -117 : Should be -117
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 948!' != 948 : Should be 948
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 714!' != 714 : Should be 714
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 808' != 808 : Should be 808
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 79' != 79 : Should be 79
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: -96' != -96 : Should be -96
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 790' != 790 : Should be 790
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: -562' != -562 : Should be -562
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: -356!' != -356 : Should be -356
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 790!' != 790 : Should be 790
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 982' != 982 : Should be 982
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 73' != 73 : Should be 73
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 524' != 524 : Should be 524
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 413!' != 413 : Should be 413
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este es el mayor: 180' != 180 : Should be 180
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 977!' != 977 : Should be 977
#
# ======================================================================
# FAIL: runTest (mod.testing.test_greater.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 17, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Este el mayor: 421!' != 421 : Should be 421
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.151s
#
# FAILED (failures=100)

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
lista = ["globo", "helicóptero", "café", "médico"]

def greatest(arr):
    for i in arr:
# Out:
#   File "/tmp/ipykernel_148/363385868.py", line 3
#
#     ^
# IndentationError: expected an indented block

# %%
# This will test your function 
test_greatest(greatest)

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
lista_3 = [1,5,9,6,5,8,7,4]

def sum_all(arr):
    resultado = 0
    for i in arr:
        resultado += i
    return resultado

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.123s
#
# OK

# %%
sum_all(lista_3)
# Out:
# 45

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
lista_3 = [1,5,9,6,5,8,7,4]
def mult_all(arr):
    resultado_4 = 1
    for i in arr:
        resultado_4 *= i
    return resultado_4

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.116s
#
# OK

# %%
mult_all(lista_3)
# Out:
# 302400

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
lista_3 = [5,9,6,5,8,7,4]

def oper_all(arr, oper):
    resultado_6 = 0
    if oper == "+":
        for i in arr:
            resultado_6 += i
    if oper == "*":
        resultado_6 = 1
        for i in arr:
            resultado_6 *= i
    return resultado_6

# %%
oper_all(lista_3, "*")
# Out:
# 302400

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.117s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    if n > 1:
        return n * factorial(n - 1)
    else:
        return 1

# %%
factorial(5)
# Out:
# 120

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.115s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
lista_unique = [1,5,6,1,6,2,5,3,2,5,1]
def unique(arr):
    y ={}
    for a in arr:
        if not a in y:
            y[a]=1
        else:
            y[a]+=1
    return[g for g, l in y.items() if l==max(y.values)]

# %%
unique(lista_unique)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_110/3436858974.py in <module>
# ----> 1 unique(lista_unique)
#
# /tmp/ipykernel_110/567713479.py in unique(arr)
#       7         else:
#       8             y[a]+=1
# ----> 9     return[g for g, l in y.items() if l==max(y.values)]
#
# /tmp/ipykernel_110/567713479.py in <listcomp>(.0)
#       7         else:
#       8             y[a]+=1
# ----> 9     return[g for g, l in y.items() if l==max(y.values)]
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
# This will test your function 
test_unique(unique)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# ...
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 112, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_148/567713479.py", line 9, in unique
#     return[g for g, l in y.items() if l==max(y.values)]
#   File "/tmp/ipykernel_148/567713479.py", line 9, in <listcomp>
#     return[g for g, l in y.items() if l==max(y.values)]
# TypeError: 'builtin_function_or_method' object is not iterable
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.202s
#
# FAILED (errors=100)

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
lista = [1,2,3,4,5,5,5,5,6,7]
def mode_counter(arr):
    y ={}
    for i in arr:
        if not i in y:
            y[i]=1
        else:
            y[i]+=1
    for r,l in y.items():
        if l==max(y.values()):
            return r

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.121s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
from statistics import stdev
list_stdev = [1,5,8,9,6,23,5,2,20]
def st_dev(arr):
    for i in arr:
        statistics.stdev(i)
    return ()

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ======================================================================
# ERROR: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Juana Mari/Desktop/Ironhack/LABS/lab-functions/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
#   File "/tmp/ipykernel_110/536431709.py", line 5, in st_dev
#     statistics.stdev(i)
# NameError: name 'statistics' is not defined
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.179s
#
# FAILED (errors=100)

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    pass

# %%
# This will test your function 
test_pangram(pangram)

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def sort_alpha(string):
    pass

# %%
# This will test your function 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
def check_pass(string):
    pass

# %%
# This will test your function 
test_pass(check_pass)
