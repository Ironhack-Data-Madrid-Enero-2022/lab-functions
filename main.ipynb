# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a>b:
        return a
    elif b>a:
        return b
    else:
        return a/b

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.143s
#
# OK

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
def greatest(arr):
    c = 0
    for i in arr:
        if i>c:
            c = i
    return c

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.151s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(arr):
    c = 0
    for i in arr:
        c+=i
    return c
    pass

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.143s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(arr):
    d = 1
    for i in arr:
        d*=i
    return d

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.146s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(arr, oper):
    if oper == "+":
        c = 0
        for i in arr:
            c+=i
    else:
        c= 1
        for i in arr:
            c*=i
    return c
    pass

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.146s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    c = 1
    for n in range (1,n+1):
        c *= n
    return c
    pass

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.146s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(arr):
    c = []
    d=0
    for i in arr:
        if i not in c:
            c.append(i)
    return c

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.244s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
def mode_counter(arr):
    dicc_count={}
    mode = 0
    c = 0
    for i in arr:
        key = str(i)
        if not key in dicc_count:
            dicc_count[key] = 1
        else:
            dicc_count[key] += 1
    for k,v in dicc_count.items():
        if v > c:
            c = v
            mode = int(k)
    return mode

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.155s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
from statistics import stdev
def st_dev(arr):
    mean_denom=0
    mean_num=0
    for i in arr:
        mean_num+=i
        mean_denom+=1
    mean = mean_num/mean_denom
    c=0
    c_denom = 0
    for i in arr:
        c+=(i - mean)**2
        c_denom+=1
    standard= (c/(c_denom-1))**(1/2)
    return standard

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.146s
#
# OK

# %% [markdown]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
def pangram(string):
    alphabet = "abcdefghijklmnopqrstuvwyz"
    pangramstring = string.lower()
    for i in alphabet:    
        if i in pangramstring:
            c = True
        else:
            c = False 
            break
    return c

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.052s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %% [markdown]
# ![elgif](https://media.giphy.com/media/rl2eCbijibzoY/giphy.gif)

# %%
#IMPOSIBLE!!!!!
def sort_alpha(string):
    c = []
    for i in stst:
        if i == ",":
            c = i
            count = 0
    for i in stst:
        if i == ",":
            count +=1
    #quizás si tenemos las veces que sale la coma, podemos valorar la cantidad de palabras. 
    #si tambien supieramos la posicion de estas comas en la string, podriamos hacer una lista definiendolos uno por uno. 
    for i in string in range(count):
        if i != ",":
            lista.append(i) 
    return count

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ...
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Palmira/Desktop/Ironhack/Semana1/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ['i'] != 'hrksyspk,igfbcutxb,ixqa,tjzatdzjwx,uxbg,wunsndivn' : Should be hrksyspk,igfbcutxb,ixqa,tjzatdzjwx,uxbg,wunsndivn
#
# ...
# FAIL: runTest (mod.testing.test_alpha.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Palmira/Desktop/Ironhack/Semana1/lab-functions/mod/testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# ...

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.
# `Valid special characters: # @ ! $ % & ( ) ^ * [ ] { }`

# %%
## no me ha dado tiempo a comprobar con hacer una variable para cada uno de los condicionales, y luego darle condicionales de si exite "false".
def check_pass(string):
    string = "Arq@ueroJskr!85"
    special = "#@!$%&()^*[]{}"
    alphabet = "abcdefghijklmnñopqrstuvwyz"
    alphabet_mayus = alphabet.upper()
    number = "1234567890"
    count = 0
    #al menos 8 characteres
    #al menos una lower case
    #al menos una upper case
    #al menos un special
    
    for i in string:
        count += 1
    if count<=8:
        c= False
    else:
        for i in string:  
            if i not in alphabet:
                if i not in alphabet_mayus:
                    if i not in number:
                        if i not in special:
                            c = False
                            break
            else:
                c = True
    return c

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# .FF...FFFFFFFFFF.FFF...FFF.FFFFFFF.F..FF..F.FF.FF.FF.FF.FF.FFFFF.FFF.FFF.FFFFFFFFFFFFFFF...F..F.FFFF
# ...
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Palmira/Desktop/Ironhack/Semana1/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ...
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/mnt/c/Users/Palmira/Desktop/Ironhack/Semana1/lab-functions/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: True != False : Should be False
#
# ...
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ...
